# %%
# %autosave 300
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# %config Completer.use_jedi = False
# Out:
# Autosaving every 300 seconds

# %%
import os

os.chdir(
    "/mnt/batch/tasks/shared/LS_root/mounts/clusters/copilot-model-run/code/Users/Soutrik.Chowdhury/unstructured_data_experiments"
)
print(os.getcwd())
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/copilot-model-run/code/Users/Soutrik.Chowdhury/unstructured_data_experiments

# %%
# from pdf2image import convert_from_path
# import os
# from dotenv import load_dotenv, find_dotenv
# import base64
# from IPython.display import Image, display
# import shutil
# from PIL import Image as PILImage
# from glob import glob

# %%
# from PIL import Image
# from torchvision import transforms
# import torch
# import warnings
# import matplotlib.pyplot as plt
# import matplotlib.patches as patches
# from matplotlib.patches import Patch
# from transformers import AutoModelForObjectDetection, AutoImageProcessor
# from transformers import DetrImageProcessor
# from transformers import DetrForObjectDetection
# import random
# import pytesseract
# from pytesseract import Output

# warnings.filterwarnings("ignore")

# %%
# load_dotenv(find_dotenv("dev.env"))
# Out:
# True

# %%
# def detect_and_remove_footer(image, threshold=200):
#     """
#     Detect and remove the footer containing page numbers from the image.

#     Args:
#     - image (PIL.Image): The image to be processed.
#     - threshold (int): Pixel intensity threshold to identify the footer.

#     Returns:
#     - PIL.Image: The image with the footer removed.
#     """
#     width, height = image.size
#     # Consider bottom 10% as potential footer
#     footer_height = int(height * 0.1)
#     footer_image = image.crop((0, height - footer_height, width, height))

#     # Use OCR to detect text in the footer region
#     ocr_result = pytesseract.image_to_data(
#         footer_image, output_type=Output.DICT)

#     # Check if there's a page number in the detected text
#     footer_contains_number = any(word.isdigit() for word in ocr_result["text"])

#     if footer_contains_number:
#         # Remove the footer containing the page number
#         cropped_image = image.crop((0, 0, width, height - footer_height))
#         return cropped_image
#     else:
#         # No page number detected, return the original image
#         return image

# %%
# def convert_pdf_to_images(
#     pdf_path, dest_folder, image_format="JPEG", remove_footer=True
# ):
#     """
#     Converts each page of a PDF into images and saves them in a directory.

#     Args:
#     - pdf_path (str): Path to the PDF file.
#     - dest_folder (str): Destination folder to save the images.
#     - image_format (str): Format to save the images (default is "JPEG").

#     Returns:
#     - list: List of image file paths saved.
#     """

#     file_name = pdf_path.split("/")[-1].split(".")[0]
#     file_version = pdf_path.split("/")[-2]
#     contractor_name = pdf_path.split("/")[-3]

#     pdf_name = f"{contractor_name}__{file_version}__{file_name}"
#     output_dir = os.path.join(dest_folder, f"{pdf_name}_images")
#     if os.path.exists(output_dir):
#         # remove the existing directory
#         shutil.rmtree(output_dir)
#     os.makedirs(output_dir, exist_ok=True)

#     images = convert_from_path(pdf_path)
#     saved_image_paths = []

#     for i, img in enumerate(images):
#         if remove_footer:
#             img = detect_and_remove_footer(img)
#         image_path = os.path.join(
#             output_dir, f"page{int(i+1)}.{image_format.lower()}")
#         img.save(image_path, image_format)
#         saved_image_paths.append(image_path)

#     return saved_image_paths

# %%
# root_folder = os.path.join(os.getcwd(), "contracts/Accenture")
# pdf_files = glob(os.path.join(root_folder, "**", "*.pdf"), recursive=True)

# %%
# file_a = pdf_files[0]
# print(file_a)
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/copilot-model-run/code/Users/Soutrik.Chowdhury/unstructured_data_experiments/contracts/Accenture/Original/MSA Completely Signed Accenture.pdf

# %%
# saved_paths = convert_pdf_to_images(file_a, "image_extracts")
# print("Images saved to:", saved_paths)
# Out:
# Images saved to: ['image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page1.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page2.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page3.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page4.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page5.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page6.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page7.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page8.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page9.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page10.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page11.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page12.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page13.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page14.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page15.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page16.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page17.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page18.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page19.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page20.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page21.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page22.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page23.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page24.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page25.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page26.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page27.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page28.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page29.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page30.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page31.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page32.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page33.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page34.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page35.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page36.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page37.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page38.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page39.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page40.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page41.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page42.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page43.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page44.jpeg', 'image_extracts/Accenture__Orig ...

# %%
# # adding paths to each image file
# img_folder_names = os.listdir("image_extracts")
# print(img_folder_names)
# file_name = img_folder_names[-2]
# docs_ls = os.listdir(f"image_extracts/{file_name}")
# docs_ls = [os.path.join(f"image_extracts/{file_name}", doc) for doc in docs_ls]
# print(len(docs_ls))
# Out:
# ['1. MSA Gateware (Enteron) 1_images', 'Accenture__Original__MSA Completely Signed Accenture_images', 'sample']
# 99

# %%
# device = "cuda" if torch.cuda.is_available() else "cpu"
# device = "cpu"
# detection_model_name = "microsoft/table-transformer-detection"

# %%
# def read_images(file_path, plot=True):
#     """Read image from file path and display it."""
#     image = Image.open(file_path).convert("RGB")
#     if plot:
#         width, height = image.size
#         fig, ax = plt.subplots(1, figsize=(12, 12))
#         img = image.resize((int(width * 0.5), int(height * 0.5)))
#         ax.imshow(img)
#         plt.axis("off")
#         plt.show()

#         return image

# %%
# sample_file_path = docs_ls[random.randint(0, len(docs_ls) - 1)]
# print(sample_file_path)
# Out:
# image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page78.jpeg

# %%
# image = read_images(sample_file_path)

# %%
# def get_model(detection_model_name, device):
#     """Load the model and image processor."""
#     image_processor = AutoImageProcessor.from_pretrained(
#         detection_model_name, force_download=True
#     )
#     model = AutoModelForObjectDetection.from_pretrained(
#         detection_model_name, revision="no_timm"
#     )
#     model.to(device)

#     return model, image_processor

# %%
# detection_model, image_processor = get_model(detection_model_name, device)
# Out:
# The `max_size` parameter is deprecated and will be removed in v4.26. Please specify in `size['longest_edge'] instead`.

# %%
# # update id2label to include "no object"
# id2label = detection_model.config.id2label
# id2label[len(detection_model.config.id2label)] = "no object"

# %%
# def model_prediction(image, detection_model, image_processor):
#     """Get model predictions."""
#     pixel_values_img = image_processor(image, return_tensors="pt")
#     with torch.no_grad():
#         outputs = detection_model(**pixel_values_img)

#     return outputs

# %%
# outputs = model_prediction(image, detection_model, image_processor)

# %%
# type(outputs)

# %%
# # for output bounding box post-processing
# def box_cxcywh_to_xyxy(x):
#     """Convert bounding boxes from [x, y, w, h] format to [x1, y1, x2, y2] format."""
#     x_c, y_c, w, h = x.unbind(-1)
#     b = [(x_c - 0.5 * w), (y_c - 0.5 * h), (x_c + 0.5 * w), (y_c + 0.5 * h)]
#     return torch.stack(b, dim=1)


# def rescale_bboxes(out_bbox, size):
#     """Rescale bounding boxes from [0, 1] to image size."""
#     img_w, img_h = size
#     b = box_cxcywh_to_xyxy(out_bbox)
#     b = b * torch.tensor([img_w, img_h, img_w, img_h], dtype=torch.float32)
#     return b


# def outputs_to_objects(outputs, img_size, id2label):
#     """Convert model outputs to objects list"""
#     m = outputs.logits.softmax(-1).max(-1)
#     pred_labels = list(m.indices.detach().cpu().numpy())[0]
#     pred_scores = list(m.values.detach().cpu().numpy())[0]
#     pred_bboxes = outputs["pred_boxes"].detach().cpu()[0]
#     pred_bboxes = [elem.tolist()
#                    for elem in rescale_bboxes(pred_bboxes, img_size)]

#     objects = []
#     for label, score, bbox in zip(pred_labels, pred_scores, pred_bboxes):
#         class_label = id2label[int(label)]
#         if not class_label == "no object":
#             objects.append(
#                 {
#                     "label": class_label,
#                     "score": float(score),
#                     "bbox": [float(elem) for elem in bbox],
#                 }
#             )

#     return objects

# %%
# op_objects = outputs_to_objects(outputs, image.size, id2label)

# %%
# def target_post_processing(image, outputs, threshold):
#     """Post-process the target objects."""
#     target_sizes = torch.tensor([image.size[::-1]])
#     results = image_processor.post_process_object_detection(
#         outputs, threshold=threshold, target_sizes=target_sizes
#     )[0]
#     return results

# %%
# results = target_post_processing(image, outputs, threshold=0.7)

# %%
# def get_table_bbox(results, detection_model):
#     """Get table bounding box coordinates."""
#     tables_coordinates = []

#     # iterate through all the detected table data
#     for score, label, box in zip(
#         results["scores"], results["labels"], results["boxes"]
#     ):
#         # Convert tensor to list and then round the elements
#         box = [round(i.item(), 2) for i in box]

#         # store bbox coodinates in Pascal VOC format for later use
#         table_dict = {"xmin": box[0], "ymin": box[1],
#                       "xmax": box[2], "ymax": box[3]}

#         tables_coordinates.append(table_dict)

#         # print prediction label, prediction confidence score, and bbox values
#         print(
#             f"Detected {detection_model.config.id2label[label.item()]} with confidence "
#             f"{round(score.item(), 3)} at location {box}"
#         )

#     return tables_coordinates

# %%
# tables_coordinates = get_table_bbox(results, detection_model)

# %%
# def image_table_detection(
#     sample_file_path, detection_model, image_processor, threshold=0.8
# ):
#     """Get table detection results."""
#     image = read_images(sample_file_path)
#     outputs = model_prediction(image, detection_model, image_processor)
#     results = target_post_processing(image, outputs, threshold)
#     tables_coordinates = get_table_bbox(results, detection_model)
#     page_name = sample_file_path.split("/")[-1].split(".")[0]

#     op_dict = {page_name: 1 if len(tables_coordinates) > 0 else 0}
#     return op_dict

# %%
# op_dict = image_table_detection(
#     sample_file_path, detection_model, image_processor)

# %% [markdown]
# #### Optimizing the code for batch processing

# %%
import os
import shutil
import random
import warnings
from glob import glob
from PIL import Image as PILImage
import torch
import matplotlib.pyplot as plt
from transformers import AutoModelForObjectDetection, AutoImageProcessor
from dotenv import load_dotenv, find_dotenv
from pdf2image import convert_from_path
from PIL import Image
from PIL import ImageOps
import numpy as np
import pytesseract
from pytesseract import Output

# Suppress warnings
warnings.filterwarnings("ignore")

# %%
# Load environment variables
load_dotenv(find_dotenv("dev.env"))
# Out:
# True

# %%
def detect_and_remove_footer(image, threshold=200):
    """
    Detect and remove the footer containing page numbers from the image.

    Args:
    - image (PIL.Image): The image to be processed.
    - threshold (int): Pixel intensity threshold to identify the footer.

    Returns:
    - PIL.Image: The image with the footer removed.
    """
    width, height = image.size
    # Consider bottom 10% as potential footer
    footer_height = int(height * 0.1)
    footer_image = image.crop((0, height - footer_height, width, height))

    # Use OCR to detect text in the footer region
    ocr_result = pytesseract.image_to_data(
        footer_image, output_type=Output.DICT)

    # Check if there's a page number in the detected text
    footer_contains_number = any(word.isdigit() for word in ocr_result["text"])

    if footer_contains_number:
        # Remove the footer containing the page number
        cropped_image = image.crop((0, 0, width, height - footer_height))
        return cropped_image
    else:
        # No page number detected, return the original image
        return image

# %%
def convert_pdf_to_images(
    pdf_path, dest_folder, image_format="JPEG", remove_footer=True
):
    """
    Converts each page of a PDF into images and saves them in a directory.

    Args:
    - pdf_path (str): Path to the PDF file.
    - dest_folder (str): Destination folder to save the images.
    - image_format (str): Format to save the images (default is "JPEG").

    Returns:
    - list: List of image file paths saved.
    """

    file_name = pdf_path.split("/")[-1].split(".")[0]
    file_version = pdf_path.split("/")[-2]
    contractor_name = pdf_path.split("/")[-3]

    pdf_name = f"{contractor_name}__{file_version}__{file_name}"
    output_dir = os.path.join(dest_folder, f"{pdf_name}_images")
    if os.path.exists(output_dir):
        # remove the existing directory
        shutil.rmtree(output_dir)
    os.makedirs(output_dir, exist_ok=True)

    images = convert_from_path(pdf_path)
    saved_image_paths = []

    for i, img in enumerate(images):
        if remove_footer:
            img = detect_and_remove_footer(img)
        image_path = os.path.join(
            output_dir, f"page{int(i+1)}.{image_format.lower()}")
        img.save(image_path, image_format)
        saved_image_paths.append(image_path)

    return saved_image_paths

# %%
root_folder = os.path.join(os.getcwd(), "contracts/Accenture")
pdf_files = glob(os.path.join(root_folder, "**", "*.pdf"), recursive=True)

# %%
file_a = pdf_files[0]
print(file_a)
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/copilot-model-run/code/Users/Soutrik.Chowdhury/unstructured_data_experiments/contracts/Accenture/Original/MSA Completely Signed Accenture.pdf

# %%
saved_paths = convert_pdf_to_images(file_a, "image_extracts")
print("Images saved to:", saved_paths)
# Out:
# Images saved to: ['image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page1.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page2.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page3.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page4.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page5.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page6.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page7.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page8.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page9.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page10.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page11.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page12.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page13.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page14.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page15.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page16.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page17.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page18.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page19.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page20.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page21.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page22.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page23.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page24.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page25.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page26.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page27.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page28.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page29.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page30.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page31.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page32.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page33.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page34.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page35.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page36.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page37.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page38.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page39.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page40.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page41.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page42.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page43.jpeg', 'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page44.jpeg', 'image_extracts/Accenture__Orig ...

# %%
def crop_whitespaces(image, padding=5, plot=False):
    """
    Crop the image to remove whitespace around the content.

    Args:
    - file_path (str): Path to the image file.
    - padding (int): Padding around the content to keep.

    Returns:
    - PIL.Image: Cropped image.
    """
    padding = 5
    padding = np.asarray([-1 * padding, -1 * padding, padding, padding])

    # invert image (so that white is 0)
    invert_im = ImageOps.invert(image)
    imageBox = invert_im.getbbox()
    imageBox = tuple(np.asarray(imageBox) + padding)

    cropped_image = image.crop(imageBox)

    if plot:
        width, height = cropped_image.size
        fig, ax = plt.subplots(1, figsize=(12, 12))
        plt.title("Cropped Image")
        img = cropped_image.resize((int(width * 0.5), int(height * 0.5)))
        ax.imshow(img)
        plt.axis("off")
        plt.show()

    return cropped_image

# %%
def read_images(file_path, plot=True, crop_whites=True):
    """Read image from file path and optionally display it."""
    image = Image.open(file_path).convert("RGB")
    if plot:
        img_resized = image.resize((int(image.width * 0.5), int(image.height * 0.5)))
        plt.figure(figsize=(12, 12))
        plt.title("Original Image")
        plt.imshow(img_resized)
        plt.axis("off")
        plt.show()

    if crop_whites:
        image = crop_whitespaces(image, plot=plot)

    return image

# %%
def get_model(detection_model_name, device):
    """Load the model and image processor."""
    image_processor = AutoImageProcessor.from_pretrained(
        detection_model_name, force_download=True
    )
    model = AutoModelForObjectDetection.from_pretrained(
        detection_model_name, revision="no_timm"
    ).to(device)
    return model, image_processor

# %%
def model_prediction(image, detection_model, image_processor):
    """Get model predictions."""
    pixel_values_img = image_processor(image, return_tensors="pt")
    with torch.no_grad():
        outputs = detection_model(**pixel_values_img)
    return outputs

# %%
def box_cxcywh_to_xyxy(x):
    """Convert bounding boxes from [x, y, w, h] format to [x1, y1, x2, y2] format."""
    x_c, y_c, w, h = x.unbind(-1)
    return torch.stack(
        [(x_c - 0.5 * w), (y_c - 0.5 * h), (x_c + 0.5 * w), (y_c + 0.5 * h)], dim=1
    )

# %%
def rescale_bboxes(out_bbox, size):
    """Rescale bounding boxes from [0, 1] to image size."""
    img_w, img_h = size
    return box_cxcywh_to_xyxy(out_bbox) * torch.tensor(
        [img_w, img_h, img_w, img_h], dtype=torch.float32
    )

# %%
def outputs_to_objects(outputs, img_size, id2label):
    """Convert model outputs to objects list."""
    m = outputs.logits.softmax(-1).max(-1)
    pred_labels = m.indices[0].cpu().numpy()
    pred_scores = m.values[0].cpu().numpy()
    pred_bboxes = rescale_bboxes(outputs["pred_boxes"][0].cpu(), img_size)

    return [
        {"label": id2label[int(label)], "score": float(score), "bbox": bbox.tolist()}
        for label, score, bbox in zip(pred_labels, pred_scores, pred_bboxes)
        if id2label[int(label)] != "no object"
    ]

# %%
def target_post_processing(image, outputs, threshold, image_processor):
    """Post-process the target objects."""
    target_sizes = torch.tensor([image.size[::-1]])
    return image_processor.post_process_object_detection(
        outputs, threshold=threshold, target_sizes=target_sizes
    )[0]

# %%
def contains_non_white_pixels(image, bbox):
    """Check if a bounding box region contains non-white pixels."""
    xmin, ymin, xmax, ymax = map(int, bbox)
    cropped_img = image.crop((xmin, ymin, xmax, ymax))
    pixels = cropped_img.getdata()
    non_white_pixels = any(pixel != (255, 255, 255) for pixel in pixels)

    return non_white_pixels

# %%
def get_table_bbox(image, results, detection_model):
    """Get table bounding box coordinates."""
    tables_coordinates = []

    for score, label, box in zip(
        results["scores"], results["labels"], results["boxes"]
    ):
        box = [round(i.item(), 2) for i in box]
        if contains_non_white_pixels(image, box):
            table_dict = {
                "xmin": box[0],
                "ymin": box[1],
                "xmax": box[2],
                "ymax": box[3],
            }
            tables_coordinates.append(table_dict)
            print(
                f"Detected {detection_model.config.id2label[label.item()]} with confidence "
                f"{round(score.item(), 3)} at location {box}"
            )

    return tables_coordinates

# %%
def image_table_detection(
    sample_file_path, detection_model, image_processor, threshold=0.85
):
    """Get table detection results."""
    image = read_images(sample_file_path)
    outputs = model_prediction(image, detection_model, image_processor)
    results = target_post_processing(image, outputs, threshold, image_processor)
    print(f"Detected labels {results['labels']} objects.")
    print(f"Detected scores{results['scores']} objects.")
    tables_coordinates = get_table_bbox(image, results, detection_model)
    return {sample_file_path: int(bool(tables_coordinates))}

# %%
# Script execution
root_folder = os.path.join(os.getcwd(), "contracts/Accenture")
pdf_files = glob(os.path.join(root_folder, "**", "*.pdf"), recursive=True)
file_a = pdf_files[0]
print(file_a)
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/copilot-model-run/code/Users/Soutrik.Chowdhury/unstructured_data_experiments/contracts/Accenture/Original/MSA Completely Signed Accenture.pdf

# %%
img_folder_names = os.listdir("image_extracts")
file_name = img_folder_names[-2]
docs_ls = [
    os.path.join("image_extracts", file_name, doc)
    for doc in os.listdir(f"image_extracts/{file_name}")
]
print(len(docs_ls))
# Out:
# 99

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device = "cpu"
detection_model_name = "microsoft/table-transformer-detection"
detection_model, image_processor = get_model(detection_model_name, device)
# Out:
# The `max_size` parameter is deprecated and will be removed in v4.26. Please specify in `size['longest_edge'] instead`.

# %%
sample_file_path = random.choice(docs_ls)
print(sample_file_path)
# Out:
# image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page39.jpeg

# %%
op_dict = image_table_detection(
    sample_file_path, detection_model, image_processor)
print(op_dict)
# Out:
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# {'image_extracts/Accenture__Original__MSA Completely Signed Accenture_images/page39.jpeg': 0}

# %%
from joblib import Parallel, delayed

# %%
def parallel_image_table_detection(
    all_file_paths, detection_model, image_processor, threshold=0.7, n_jobs=-1
):
    """
    Run image_table_detection in parallel for multiple sample file paths.

    Args:
    - sample_file_paths (list): List of file paths to be processed.
    - detection_model: Loaded object detection model.
    - image_processor: Image processor corresponding to the model.
    - threshold (float): Confidence threshold for post-processing.
    - n_jobs (int): Number of jobs to run in parallel (default is -1 for all cores).

    Returns:
    - list: List of dictionaries with detection results for each file path.
    """
    results = Parallel(n_jobs=n_jobs)(
        delayed(image_table_detection)(
            file_path, detection_model, image_processor, threshold
        )
        for file_path in all_file_paths
    )
    return results

# %%
# Example usage
op_results = parallel_image_table_detection(
    docs_ls, detection_model, image_processor)
# Out:
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0, 0]) objects.
# Detected scorestensor([0.7326, 0.8554]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.8787]) objects.
# Detected table with confidence 0.879 at location [187.61, 1649.04, 1384.43, 2051.83]
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.8244]) objects.
# Detected table with confidence 0.824 at location [176.1, 1295.17, 1406.95, 1740.19]
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.7955]) objects.
# Detected table with confidence 0.795 at location [161.64, 842.53, 1410.28, 2060.77]
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.7436]) objects.
# Detected table with confidence 0.744 at location [252.76, 1532.71, 1404.43, 1985.27]
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.8266]) objects.
# Detected table with confidence 0.827 at location [153.49, 1691.25, 1383.45, 2127.0]
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.9687]) objects.
# Detected table with confidence 0.969 at location [157.18, 250.52, 1357.14, 683.53]
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.8097]) objects.
# Detected table with confidence 0.81 at location [203.6, 1642.61, 1364.02, 2037.05]
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.7807]) objects.
# Detected table with confidence 0.781 at location [160.44, 1644.6, 1380.11, 2086.69]
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.7175]) objects.
# Detected table with confidence 0.718 at location [161.39, 981.69, 1405.62, 2062.28]
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.7001]) objects.
# Detected table with confidence 0.7 at location [311.59, 1577.41, 1375.87, 2111.38]
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0, 0]) objects.
# Detected scorestensor([0.7347, 0.7961]) objects.
# Detected table with confidence 0.735 at location [158.7, 1136.84, 1375.45, 1987.14]
# Detected table with confidence 0.796 at location [159.02, 978.84, 1397.97, 2010.69]
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.7532]) objects.
# Detected table with confidence 0.753 at location [185.65, 1832.68, 1362.05, 2119.11]
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.7695]) objects.
# Detected table with confidence 0.77 at location [380.72, 1784.39, 1398.06, 1958.46]
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.9416]) objects.
# Detected table with confidence 0.942 at location [248.05, 176.22, 1331.65, 652.26]
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.9979]) objects.
# Detected table with confidence 0.998 at location [545.1, 1222.66, 1040.49, 1537.64]
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.9304]) objects.
# Detected table with confidence 0.93 at location [164.65, 1345.79, 643.09, 1522.79]
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.9747]) objects.
# Detected table with confidence 0.975 at location [472.38, 376.06, 1974.78, 1417.69]
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.9998]) objects.
# Detected table with confidence 1.0 at location [159.48, 249.91, 1967.64, 1137.68]
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.9733]) objects.
# Detected table with confidence 0.973 at location [263.52, 190.94, 2012.06, 1547.83]
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.9998]) objects.
# Detected table with confidence 1.0 at location [261.62, 282.73, 2004.58, 963.71]
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.9999]) objects.
# Detected table with confidence 1.0 at location [265.66, 186.16, 2011.84, 1142.19]
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.9999]) objects.
# Detected table with confidence 1.0 at location [263.97, 218.43, 2016.86, 733.71]
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.9998]) objects.
# Detected table with confidence 1.0 at location [265.42, 216.57, 1989.54, 1216.23]
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.9999]) objects.
# Detected table with confidence 1.0 at location [264.33, 219.05, 2007.76, 1331.76]
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.9998]) objects.
# Detected table with confidence 1.0 at location [264.86, 217.77, 1973.44, 1138.76]
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.7836]) objects.
# Detected table with confidence 0.784 at location [352.92, 1779.28, 1404.12, 2018.39]
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.9997]) objects.
# Detected table with confidence 1.0 at location [262.6, 214.9, 1935.2, 1111.65]
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.9485]) objects.
# Detected table with confidence 0.949 at location [158.7, 165.62, 1443.09, 661.56]
# Figure(1200x1200)
# Detected labels tensor([1]) objects.
# Detected scorestensor([0.8371]) objects.
# Detected table rotated with confidence 0.837 at location [162.61, 213.45, 1440.79, 1927.06]
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.9873]) objects.
# Detected table with confidence 0.987 at location [171.63, 643.32, 1405.2, 1952.39]
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.8044]) objects.
# Detected table with confidence 0.804 at location [176.19, 197.87, 1398.17, 1363.24]
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.9999]) objects.
# Detected table with confidence 1.0 at location [182.01, 184.19, 1318.21, 1965.12]
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.9999]) objects.
# Detected table with confidence 1.0 at location [183.33, 186.76, 1320.55, 1950.03]
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.9999]) objects.
# Detected table with confidence 1.0 at location [186.45, 185.11, 1327.19, 378.37]
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.9999]) objects.
# Detected table with confidence 1.0 at location [183.43, 183.87, 1318.67, 1918.1]
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.9999]) objects.
# Detected table with confidence 1.0 at location [181.94, 184.61, 1318.25, 1959.23]
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Detected labels tensor([1]) objects.
# Detected scorestensor([0.9976]) objects.
# Detected labels tensor([0, 0]) objects.
# Detected scorestensor([0.9993, 0.9957]) objects.
# Detected table with confidence 0.999 at location [175.26, 749.69, 921.09, 873.0]
# Detected table with confidence 0.996 at location [172.8, 306.36, 925.16, 535.65]
# Detected table rotated with confidence 0.998 at location [158.77, 164.42, 781.28, 1873.66]
# Figure(1200x1200)
# Detected labels tensor([1]) objects.
# Detected scorestensor([0.9977]) objects.
# Detected table rotated with confidence 0.998 at location [161.7, 168.91, 941.52, 1818.88]
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([1]) objects.
# Detected scorestensor([0.9780]) objects.
# Detected table rotated with confidence 0.978 at location [189.07, 199.02, 1454.4, 1935.61]
# Figure(1200x1200)
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.8127]) objects.
# Detected table with confidence 0.813 at location [174.5, 362.81, 1451.5, 1956.96]
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.7787]) objects.
# Detected table with confidence 0.779 at location [165.33, 1020.03, 1398.3, 2003.54]
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.9945]) objects.
# Detected table with confidence 0.994 at location [263.32, 721.89, 1441.73, 1853.65]
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([1]) objects.
# Detected scorestensor([0.9906]) objects.
# Detected table rotated with confidence 0.991 at location [171.68, 173.68, 686.52, 1960.3]
# Detected labels tensor([1]) objects.
# Detected scorestensor([0.9853]) objects.
# Detected table rotated with confidence 0.985 at location [160.47, 214.3, 1036.19, 1959.65]
# Figure(1200x1200)
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.9918]) objects.
# Detected table with confidence 0.992 at location [281.29, 1143.02, 1455.89, 1843.48]
# Figure(1200x1200)
# Detected labels tensor([1]) objects.
# Detected scorestensor([0.9930]) objects.
# Detected table rotated with confidence 0.993 at location [162.38, 177.1, 591.51, 1958.15]
# Figure(1200x1200)
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([1]) objects.
# Detected scorestensor([0.9948]) objects.
# Detected table rotated with confidence 0.995 at location [162.68, 183.37, 670.01, 1962.62]
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([1]) objects.
# Detected scorestensor([0.9962]) objects.
# Detected table rotated with confidence 0.996 at location [159.75, 162.59, 599.97, 1246.7]
# Figure(1200x1200)
# Figure(1200x1200)
# Detected labels tensor([1]) objects.
# Detected scorestensor([0.9087]) objects.
# Detected table rotated with confidence 0.909 at location [161.03, 220.45, 826.98, 1796.03]
# Detected labels tensor([], dtype=torch.int64) objects.
# Detected scorestensor([]) objects.
# Detected labels tensor([0]) objects.
# Detected scorestensor([0.9546]) objects.
# Detected table with confidence 0.955 at location [143.02, 439.84, 1075.02, 610.58]

# %%
all_dict = {}
for result in op_results:
    all_dict.update(result)

# %%
all_dict
# Out:
# {'page0': 1,
#  'page1': 1,
#  'page10': 1,
#  'page11': 0,
#  'page12': 0,
#  'page13': 0,
#  'page14': 0,
#  'page15': 0,
#  'page16': 0,
#  'page17': 0,
#  'page18': 1,
#  'page19': 1,
#  'page2': 1,
#  'page20': 0,
#  'page21': 0,
#  'page22': 0,
#  'page23': 0,
#  'page24': 1,
#  'page25': 1,
#  'page26': 0,
#  'page27': 1,
#  'page28': 0,
#  'page29': 0,
#  'page3': 1,
#  'page30': 0,
#  'page31': 0,
#  'page32': 0,
#  'page33': 0,
#  'page34': 0,
#  'page35': 1,
#  'page36': 0,
#  'page37': 0,
#  'page38': 0,
#  'page39': 0,
#  'page4': 1,
#  'page40': 0,
#  'page41': 1,
#  'page42': 0,
#  'page43': 1,
#  'page44': 0,
#  'page45': 0,
#  'page46': 0,
#  'page47': 0,
#  'page48': 0,
#  'page49': 0,
#  'page5': 1,
#  'page50': 1,
#  'page51': 1,
#  'page52': 0,
#  'page53': 0,
#  'page54': 0,
#  'page55': 0,
#  'page56': 0,
#  'page57': 1,
#  'page58': 1,
#  'page59': 1,
#  'page6': 0,
#  'page60': 1,
#  'page61': 1,
#  'page62': 1,
#  'page63': 1,
#  'page64': 1,
#  'page65': 1,
#  'page66': 1,
#  'page67': 1,
#  'page68': 1,
#  'page69': 1,
#  'page7': 1,
#  'page70': 1,
#  'page71': 1,
#  'page72': 0,
#  'page73': 1,
#  'page74': 1,
#  'page75': 0,
#  'page76': 1,
#  'page77': 1,
#  'page78': 1,
#  'page79': 1,
#  'page8': 1,
#  'page80': 1,
#  'page81': 1,
#  'page82': 1,
#  'page83': 1,
#  'page84': 1,
#  'page85': 1,
#  'page86': 1,
#  'page87': 1,
#  'page88': 1,
#  'page89': 1,
#  'page9': 0,
#  'page90': 1,
#  'page91': 1,
#  'page92': 0,
#  'page93': 1,
#  'page94': 1,
#  'page95': 1,
#  'page96': 1,
#  'page97': 0,
#  'page98': 1}

# %% [markdown]
# Reference:
# * https://huggingface.co/docs/transformers/main/en/model_doc/table-transformer

# %% [markdown]
# ##################################################################################################################################
